# %%
# import important packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
from sklearn.model_selection import train_test_split 
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pandas_profiling

from matplotlib import rcParams
import warnings 

warnings.filterwarnings("ignore")

# figure size in inches 
rcParams["figure.figsize"] = 10, 6 
np.random.seed(42)

# %%
data1 = pd.read_csv(r"./eda_data.csv")

# %%
data1.sample(5)
# Out:
#      Unnamed: 0                        Job Title  \
# 120         120                   Data Scientist
# 196         196           Marketing Data Analyst
# 336         336  Senior Scientist (Neuroscience)
# 582         582      Senior LiDAR Data Scientist
# 395         395           Lead Big Data Engineer
#
#                   Salary Estimate  \
# 120   $77K-$124K (Glassdoor est.)
# 196    $35K-$62K (Glassdoor est.)
# 336  $109K-$200K (Glassdoor est.)
# 582   $93K-$151K (Glassdoor est.)
# 395  $121K-$203K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 120  Company Description:\nWhats it like to work at...     4.4
# 196  Under direct supervision of the Director of Da...     3.6
# 336  Sunovion Pharmaceuticals is looking for a Seni...     3.5
# 582  Overview\n\n\nLuminar is an autonomous vehicle...     3.9
# 395  Our mission is to help people everywhere find ...     4.0
#
#                   Company Name           Location     Headquarters  \
# 120            Quick Base\n4.4      Cambridge, MA    Cambridge, MA
# 196     San Manuel Casino\n3.6       Highland, CA     Highland, CA
# 336              Sunovion\n3.5    Marlborough, MA  Marlborough, MA
# 582  Luminar Technologies\n3.9        Orlando, FL      Orlando, FL
# 395             Glassdoor\n4.0  San Francisco, CA  Mill Valley, CA
#
#                        Size  Founded  ... age python_yn R_yn spark aws  excel  \
# 120    201 to 500 employees     1999  ...  21         1    0     0   0      1
# 196  1001 to 5000 employees     1986  ...  34         0    0     0   0      1
# 336  1001 to 5000 employees     2010  ...  10         1    0     0   0      1
# 582    201 to 500 employees     2012  ...   8         1    0     0   1      0
# 395  1001 to 5000 employees     2007  ...  13         1    0     1   1      1
#
#            job_simp  seniority  desc_len  num_comp
# 120  data scientist         na      4188         0
# 196         analyst         na      4608         0
# 336              na     senior      4517         3
# 582  data scientist     senior      5647         0
# 395   data engineer     senior      3978         2
#
# [5 rows x 33 columns]

# %%
data2 = pd.read_csv(r"./glassdoor_jobs.csv")

# %%
data3 = pd.read_csv(r"./salary_data_cleaned.csv")

# %%
data2.sample(5)
# Out:
#      Unnamed: 0              Job Title               Salary Estimate  \
# 207         207  Senior Data Scientist   $73K-$124K (Glassdoor est.)
# 350         350         Data Scientist   $76K-$126K (Glassdoor est.)
# 205         205    Senior Data Analyst   $55K-$100K (Glassdoor est.)
# 49           49    Lead Data Scientist  $158K-$211K (Glassdoor est.)
# 188         188   Staff Data Scientist  $132K-$211K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 207  The Senior Data Scientist independently develo...     3.3
# 350  Roles and responsibilities include the followi...     2.3
# 205  As a precaution and in compliance with applica...     2.8
# 49   As the world's leader in digital payments tech...     3.7
# 188  Western\nDigital\nThe next big thing in data i...     3.5
#
#                      Company Name        Location     Headquarters  \
# 207  Plymouth Rock Assurance\n3.3  Woodbridge, NJ       Boston, MA
# 350    Vanda Pharmaceuticals\n2.3  Washington, DC   Washington, DC
# 205   Dodge Data & Analytics\n2.8    Hamilton, NJ     Hamilton, NJ
# 49                 Visa Inc.\n3.7    Bellevue, WA  Foster City, CA
# 188          Western Digital\n3.5    San Jose, CA     San Jose, CA
#
#                        Size  Founded  Type of ownership  \
# 207  1001 to 5000 employees     1982  Company - Private
# 350    201 to 500 employees     2003   Company - Public
# 205    201 to 500 employees     2014  Company - Private
# 49         10000+ employees     1958   Company - Public
# 188        10000+ employees     1970   Company - Public
#
#                          Industry                     Sector  \
# 207            Insurance Carriers                  Insurance
# 350     Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
# 205                   IT Services     Information Technology
# 49                    IT Services     Information Technology
# 188  Computer Hardware & Software     Information Technology
#
#                         Revenue                             Competitors
# 207    $10 to $25 million (USD)     Arbella Insurance, Safety Insurance
# 350  $100 to $500 million (USD)                                      -1
# 205    Unknown / Non-Applicable                                      -1
# 49           $10+ billion (USD)  American Express, Mastercard, Discover
# 188          $10+ billion (USD)             Seagate Technology, Toshiba

# %%
data3.sample(5)
# Out:
#                                              Job Title  \
# 384                 Sr Data Engineer (Sr BI Developer)
# 725          Senior Scientist - Regulatory Submissions
# 61                                      Data Scientist
# 411  RESEARCH COMPUTER SCIENTIST - RESEARCH ENGINEE...
# 483                                     Data Scientist
#
#                  Salary Estimate  \
# 384    $90K-$110K(Employer est.)
# 725  $80K-$155K (Glassdoor est.)
# 61   $84K-$146K (Glassdoor est.)
# 411   $52K-$91K (Glassdoor est.)
# 483   $56K-$95K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 384  Description/Responsibilities\n\n\nResponsible ...     3.4
# 725  British American Tobacco\nReynolds American In...     3.1
# 61   USEReady is looking for 2-3 Data Scientist to ...     4.3
# 411  Serve as a software developer and researcher o...     3.9
# 483  ExecOnline is a fast-growing, venture-backed e...     4.2
#
#                           Company Name           Location       Headquarters  \
# 384                 Tivity Health\n3.4       Chandler, AZ       Franklin, TN
# 725             Reynolds American\n3.1  Winston-Salem, NC  Winston-Salem, NC
# 61                       USEReady\n4.3       New York, NY       New York, NY
# 411  Southwest Research Institute\n3.9    San Antonio, TX    San Antonio, TX
# 483                    ExecOnline\n4.2       New York, NY       New York, NY
#
#                         Size  Founded       Type of ownership  ... avg_salary  \
# 384    501 to 1000 employees     1981        Company - Public  ...      100.0
# 725  5001 to 10000 employees     1875       Company - Private  ...      117.5
# 61      201 to 500 employees     2011       Company - Private  ...      115.0
# 411   1001 to 5000 employees     1947  Nonprofit Organization  ...       71.5
# 483      51 to 200 employees     2012       Company - Private  ...       75.5
#
#                         company_txt job_state same_state  age  python_yn  \
# 384                 Tivity Health\n        AZ          0   39          0
# 725             Reynolds American\n        NC          1  145          0
# 61                       USEReady\n        NY          1    9          1
# 411  Southwest Research Institute\n        TX          1   73          1
# 483                    ExecOnline\n        NY          1    8          1
#
#      R_yn  spark  aws excel
# 384     0      0    0     0
# 725     0      0    0     1
# 61      0      1    1     0
# 411     0      0    1     1
# 483     0      0    1     0
#
# [5 rows x 28 columns]

# %%
data1.columns
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same_state', 'age', 'python_yn', 'R_yn',
#        'spark', 'aws', 'excel', 'job_simp', 'seniority', 'desc_len',
#        'num_comp'],
#       dtype='object')

# %%
data2.columns
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors'],
#       dtype='object')

# %%
data3.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same_state', 'age', 'python_yn', 'R_yn',
#        'spark', 'aws', 'excel'],
#       dtype='object')
